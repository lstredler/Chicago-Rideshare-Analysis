# %%
import pandas as pd
import requests
from config import api_key

march_trips_file = "march2020.csv"
df = pd.read_csv(march_trips_file)
api_key
# Out:
# 'AIzaSyAQ-wLAxjY8SBClAqX0khNRfe4gvS7DIhQ'

# %%
df.columns = df.columns.str.replace(' ', '_').str.lower()
df.head()
# Out:
#                                     trip_id trip_start_timestamp  \
# 0  00019f1f256bfa706cf8641b1aa611f624325010  2020-03-01 00:15:00
# 1  000753ac45c450e21abdf1a4c961176bcfaefda3  2020-03-01 00:15:00
# 2  002ec2876ddbe0274826cdc660c2a270b99e4554  2020-03-01 00:15:00
# 3  9270c6ca6296127112be3219f702101d1d338aa4  2020-03-01 00:15:00
# 4  004be16829b751eb031b6b4f05a33542980c1940  2020-03-01 00:15:00
#
#        trip_end_timestamp  trip_seconds  trip_miles  pickup_census_tract  \
# 0  03/01/2020 12:30:00 AM         320.0         1.5         1.703184e+10
# 1  03/01/2020 12:45:00 AM        1512.0         8.8         1.703181e+10
# 2  03/01/2020 12:15:00 AM         188.0         0.6         1.703108e+10
# 3  03/01/2020 12:45:00 AM        1774.0         6.9         1.703122e+10
# 4  03/01/2020 12:30:00 AM         672.0         2.0         1.703107e+10
#
#    dropoff_census_tract  pickup_community_area  dropoff_community_area  fare  \
# ...

# %%
df_locations = df[['pickup_community_area','dropoff_community_area','pickup_centroid_latitude','pickup_centroid_longitude','dropoff_centroid_latitude','dropoff_centroid_longitude']]
df_locations_clean = df_locations.dropna()
df_locations_clean = df_locations_clean.astype({'pickup_community_area':'int32','dropoff_community_area':'int32'})
df_locations_clean.dtypes
# Out:
# pickup_community_area           int32
# dropoff_community_area          int32
# pickup_centroid_latitude      float64
# pickup_centroid_longitude     float64
# dropoff_centroid_latitude     float64
# dropoff_centroid_longitude    float64
# dtype: object

# %%
areas = requests.get('https://data.cityofchicago.org/resource/igwz-8jzy.json').json()
areas_df = pd.DataFrame(areas)[['community','area_num_1']]
areas_dict = dict(zip(areas_df.area_num_1, areas_df.community))
pd.DataFrame(areas).iloc[0][0]
# Out:
# {'type': 'MultiPolygon',
#  'coordinates': [[[[-87.60914087617894, 41.84469250265398],
#     [-87.60914874757808, 41.84466159842403],
#     [-87.6091611204126, 41.84458961193954],
#     [-87.60916766215838, 41.84451717732316],
#     [-87.60916860600166, 41.844456260738305],
#     [-87.60915012199398, 41.84423871659811],
#     [-87.60907241249289, 41.844194738881015],
#     [-87.60900627147821, 41.84410646928696],
#     [-87.6089650217216, 41.84404345755115],
#     [-87.60891566390615, 41.84395529375054],
#     [-87.60889980118988, 41.84387361649532],
#     [-87.60886701371862, 41.84380438280048],
#     [-87.6088514342449, 41.843697606960866],
#     [-87.60881089281094, 41.84357184776641],
#     [-87.60877127222787, 41.84336451715353],
#     [-87.6087215608253, 41.84330772696518],
#     [-87.6086722038968, 41.8432195630558],
#     [-87.60858152789015, 41.84307466210119],
#     [-87.60847385682872, 41.84294847915887],
#     [-87.60839135990155, 41.842822455284654],
# ...

# %%
df_locations_clean['pickup_area'] = df_locations_clean['pickup_community_area'].map(lambda x: areas_dict[str(x)])
df_locations_clean['dropoff_area'] = df_locations_clean['dropoff_community_area'].map(lambda x: areas_dict[str(x)])
df_locations_clean
# Out:
#          pickup_community_area  dropoff_community_area  \
# 0                           60                      59
# 2                            8                      32
# 3                           22                      29
# 4                            7                      22
# 5                            7                       7
# ...                        ...                     ...
# 5265922                     44                      71
# 5265923                     38                      43
# 5265924                     42                      42
# 5265926                     60                      38
# 5265927                     24                       5
#
#          pickup_centroid_latitude  pickup_centroid_longitude  \
# 0                       41.832937                 -87.653583
# 2                       41.892042                 -87.631864
# 3                       41.920802                 -87.694532
# ...

# %%
# top 30 most popular pickup areas
top_pickup_areas = df_locations_clean.pickup_area.value_counts()
top_pickup_areas.head(15).plot.bar()
top_pickup_areas
# Out:
# NEAR NORTH SIDE    681807
# NEAR WEST SIDE     392660
# LOOP               355870
# LAKE VIEW          316298
# WEST TOWN          282133
#                     ...
# EDISON PARK          3462
# MOUNT GREENWOOD      2913
# BURNSIDE             2842
# EAST SIDE            2738
# HEGEWISCH            1805
# Name: pickup_area, Length: 77, dtype: int64

# %%
# top 30 most popular dropoff areas
top_dropoff_areas = df_locations_clean.dropoff_area.value_counts().head(15)
top_dropoff_areas.plot.bar()
# Out:
# <AxesSubplot:>

# %%
popular_trips_df = df_locations_clean.groupby(['pickup_area','dropoff_area']).size().reset_index(name='count').sort_values(by='count', ascending=False).head(15)
popular_trips_df['trip'] = popular_trips_df.pickup_area + ' to ' + popular_trips_df.dropoff_area
popular_trips_df = popular_trips_df[['trip','count']].set_index('trip')
popular_trips_df.plot.bar();

# %%
pickup_coord_df = df_locations_clean.groupby(['pickup_centroid_latitude','pickup_centroid_longitude','pickup_area']).size().reset_index(name='count').sort_values(by='count', ascending=False)
pickup_coord_df
# popular_trips_df['trip'] = popular_trips_df.pickup_area + ' to ' + popular_trips_df.dropoff_area
# popular_trips_df = popular_trips_df[['trip','count']].set_index('trip')
# popular_trips_df.plot.bar();
# Out:
#      pickup_centroid_latitude  pickup_centroid_longitude      pickup_area  \
# 474                 41.880994                 -87.632746             LOOP
# 500                 41.892042                 -87.631864  NEAR NORTH SIDE
# 486                 41.885281                 -87.657233   NEAR WEST SIDE
# 484                 41.884987                 -87.620993             LOOP
# 510                 41.893216                 -87.637844  NEAR NORTH SIDE
# ..                        ...                        ...              ...
# 44                  41.703005                 -87.530712        EAST SIDE
# 25                  41.689538                 -87.540397        EAST SIDE
# 28                  41.691632                 -87.693411      MORGAN PARK
# 668                 41.936196                 -87.811606          DUNNING
# 785                 41.972105                 -87.844090            OHARE
#
#       count
# 474  142429
# 500   86370
# 486   86205
# 484   80935
# ...

# %%
import gmaps
gmaps.configure(api_key=api_key)
locations = pickup_coord_df[['pickup_centroid_latitude','pickup_centroid_longitude']]
weights = pickup_coord_df['count']
fig = gmaps.figure(center=(41.8781,-87.6298),zoom_level=12)
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
top_pickup_coord_df = pickup_coord_df.head(20)
info_box_template = """
<dl>
<dt>Area</dt><dd>{pickup_area}</dd>
<dt>pickups</dt><dd>{count}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
pickup_info = [info_box_template.format(**row) for index, row in top_pickup_coord_df.iterrows()]
locations = top_pickup_coord_df[["pickup_centroid_latitude", "pickup_centroid_longitude"]].head(20)

# %%
# Add marker layer ontop of heat map
marker_layer = gmaps.marker_layer(
    locations,
    info_box_content = pickup_info
)
fig.add_layer(marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import folium
m = folium.Map(location=[41.8781,-87.6298])
bins = list(top_pickup_areas.quantile([0, 0.25, 0.5, 0.75, 1]))
folium.Choropleth(
    geo_data='chicago-community-areas.geojson',
    name="choropleth",
    data=top_pickup_areas,
    key_on='feature.properties.community',
    bins=bins
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
chicago-community-areas.geojson
