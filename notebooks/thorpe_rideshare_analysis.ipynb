# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "march_only_trips_2020 2.csv"
original_df = pd.read_csv(file)
original_df.head()
# Out:
#                                     Trip ID Trip Start Timestamp  \
# 0  00019f1f256bfa706cf8641b1aa611f624325010  2020-03-01 00:15:00
# 1  000753ac45c450e21abdf1a4c961176bcfaefda3  2020-03-01 00:15:00
# 2  002ec2876ddbe0274826cdc660c2a270b99e4554  2020-03-01 00:15:00
# 3  9270c6ca6296127112be3219f702101d1d338aa4  2020-03-01 00:15:00
# 4  004be16829b751eb031b6b4f05a33542980c1940  2020-03-01 00:15:00
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  03/01/2020 12:30:00 AM         320.0         1.5         1.703184e+10
# 1  03/01/2020 12:45:00 AM        1512.0         8.8         1.703181e+10
# 2  03/01/2020 12:15:00 AM         188.0         0.6         1.703108e+10
# 3  03/01/2020 12:45:00 AM        1774.0         6.9         1.703122e+10
# 4  03/01/2020 12:30:00 AM         672.0         2.0         1.703107e+10
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  Fare  \
# ...

# %%
original_df.shape
# Out:
# (5265929, 21)

# %%
original_df.drop(columns=['Pickup Census Tract', 'Dropoff Census Tract', 'Pickup Community Area', 'Dropoff Community Area','Shared Trip Authorized', 'Trips Pooled', 'Pickup Centroid Location', 'Dropoff Centroid Location'])
# Out:
#                                           Trip ID Trip Start Timestamp  \
# 0        00019f1f256bfa706cf8641b1aa611f624325010  2020-03-01 00:15:00
# 1        000753ac45c450e21abdf1a4c961176bcfaefda3  2020-03-01 00:15:00
# 2        002ec2876ddbe0274826cdc660c2a270b99e4554  2020-03-01 00:15:00
# 3        9270c6ca6296127112be3219f702101d1d338aa4  2020-03-01 00:15:00
# 4        004be16829b751eb031b6b4f05a33542980c1940  2020-03-01 00:15:00
# ...                                           ...                  ...
# 5265924  fd14a92122b98bf648920df335057672a9989a92           2020-03-31
# 5265925  fd3497661c46ed6a8256c9754533a59ae61db3a0           2020-03-31
# 5265926  fd46af8ca3e78a22d3771636c46c6d7daa68d66a           2020-03-31
# 5265927  fecfa1efc9989db94a7f2a172b599f5fdcd1931a           2020-03-31
# 5265928  ff37d06f0bad1048d73ef3577509f7ac7ffa049e           2020-03-31
#
#              Trip End Timestamp  Trip Seconds  Trip Miles  Fare  Tip  \
# ...

# %%
distance_box_and_whisker = original_df.boxplot(column='Trip Miles')
distance_box_and_whisker.set_ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
original_df['Trip Miles'].max()
# Out:
# 355.3

# %%
original_df.head()
# Out:
#                                     Trip ID Trip Start Timestamp  \
# 0  00019f1f256bfa706cf8641b1aa611f624325010  2020-03-01 00:15:00
# 1  000753ac45c450e21abdf1a4c961176bcfaefda3  2020-03-01 00:15:00
# 2  002ec2876ddbe0274826cdc660c2a270b99e4554  2020-03-01 00:15:00
# 3  9270c6ca6296127112be3219f702101d1d338aa4  2020-03-01 00:15:00
# 4  004be16829b751eb031b6b4f05a33542980c1940  2020-03-01 00:15:00
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  03/01/2020 12:30:00 AM         320.0         1.5         1.703184e+10
# 1  03/01/2020 12:45:00 AM        1512.0         8.8         1.703181e+10
# 2  03/01/2020 12:15:00 AM         188.0         0.6         1.703108e+10
# 3  03/01/2020 12:45:00 AM        1774.0         6.9         1.703122e+10
# 4  03/01/2020 12:30:00 AM         672.0         2.0         1.703107e+10
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  Fare  \
# ...

# %%
#original_df['day'] = original_df['Trip Start Timestamp'].apply(lambda r:r.day)
#original_df

# %%
original_df['day'] = pd.DatetimeIndex(original_df['Trip Start Timestamp']).day
original_df
# Out:
#                                           Trip ID Trip Start Timestamp  \
# 0        00019f1f256bfa706cf8641b1aa611f624325010  2020-03-01 00:15:00
# 1        000753ac45c450e21abdf1a4c961176bcfaefda3  2020-03-01 00:15:00
# 2        002ec2876ddbe0274826cdc660c2a270b99e4554  2020-03-01 00:15:00
# 3        9270c6ca6296127112be3219f702101d1d338aa4  2020-03-01 00:15:00
# 4        004be16829b751eb031b6b4f05a33542980c1940  2020-03-01 00:15:00
# ...                                           ...                  ...
# 5265924  fd14a92122b98bf648920df335057672a9989a92           2020-03-31
# 5265925  fd3497661c46ed6a8256c9754533a59ae61db3a0           2020-03-31
# 5265926  fd46af8ca3e78a22d3771636c46c6d7daa68d66a           2020-03-31
# 5265927  fecfa1efc9989db94a7f2a172b599f5fdcd1931a           2020-03-31
# 5265928  ff37d06f0bad1048d73ef3577509f7ac7ffa049e           2020-03-31
#
#              Trip End Timestamp  Trip Seconds  Trip Miles  \
# ...

# %%
day_counts = original_df["day"].value_counts().reset_index().sort_values("index")
day_counts
# Out:
#     index     day
# 5       1  282627
# 12      2  250251
# 9       3  256751
# 7       4  265137
# 4       5  290173
# 2       6  353727
# 0       7  371954
# 6       8  270394
# 10      9  254365
# 13     10  247466
# 11     11  252835
# 8      12  258689
# 3      13  294185
# 1      14  365633
# 14     15  200115
# 15     16  146828
# 16     17  103921
# 18     18   91614
# 19     19   86224
# 17     20   92530
# 20     21   70609
# 26     22   49592
# 24     23   51552
# 27     24   49357
# 25     25   50529
# 23     26   52068
# 21     27   59866
# 22     28   54422
# 29     29   45139
# 28     30   47006
# 30     31     370

# %%
df_group = original_df.groupby(original_df["day"])

df_group

# %%
thorpe_bar = day_counts.plot.bar("index","day", xlabel = 'Day of the Month', ylabel = 'Number of Rides Per Day')
thorpe_bar
# Out:
# <AxesSubplot:xlabel='Day of the Month', ylabel='Number of Rides Per Day'>

# %%
thorpe_line = day_counts.plot.line("index","day", xlabel = 'Day of the Month', ylabel = 'Number of Rides Per Day')
thorpe_line
# Out:
# <AxesSubplot:xlabel='Day of the Month', ylabel='Number of Rides Per Day'>

# %%
plt.savefig('thorpe_day_counts_line.png')

# %%
#get line graph of shared rides (trips pooled) by day 
pooled_df = original_df.groupby(original_df["Trips Pooled"] > 1)
pooled_df
